# %%
import pandas as pd
import numpy as np

# %%
data = {'ID':[1,2,3,4,5],
        'Name':['Amit','Priya',np.nan,'Rahul',np.nan],
        'Marks':[80,np.nan,75,85,np.nan],
        'city':['Ahm','BVN',np.nan,'Surat','Rajkot']}
df = pd.DataFrame(data)
df
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya    NaN     BVN
# 2   3    NaN   75.0     NaN
# 3   4  Rahul   85.0   Surat
# 4   5    NaN    NaN  Rajkot

# %%
df.isnull()
# Out:
#       ID   Name  Marks   city
# 0  False  False  False  False
# 1  False  False   True  False
# 2  False   True  False   True
# 3  False  False  False  False
# 4  False   True   True  False

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     2
# Marks    2
# city     1
# dtype: int64

# %%
df.fillna(130)
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya  130.0     BVN
# 2   3    130   75.0     130
# 3   4  Rahul   85.0   Surat
# 4   5    130  130.0  Rajkot

# %%
df.fillna(df.mean())
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya   80.0     BVN
# 2   3    NaN   75.0     NaN
# 3   4  Rahul   85.0   Surat
# 4   5    NaN   80.0  Rajkot

# %%
df.fillna(df.median())
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya   80.0     BVN
# 2   3    NaN   75.0     NaN
# 3   4  Rahul   85.0   Surat
# 4   5    NaN   80.0  Rajkot

# %%
df.fillna(df.min())
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya   75.0     BVN
# 2   3    NaN   75.0     NaN
# 3   4  Rahul   85.0   Surat
# 4   5    NaN   75.0  Rajkot

# %%
df.fillna(df.mode())
# Out:
#    ID   Name  Marks    city
# 0   1   Amit   80.0     Ahm
# 1   2  Priya   80.0     BVN
# 2   3  Rahul   75.0  Rajkot
# 3   4  Rahul   85.0   Surat
# 4   5    NaN    NaN  Rajkot
